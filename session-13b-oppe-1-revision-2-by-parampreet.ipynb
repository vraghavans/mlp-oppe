# %% [markdown]
# # MLP Session 13b - OPPE 1 Revision 2 with Practice Questions by Parampreet Singh
# ## [Session video 🔗](https://youtu.be/4x6mFTG5oEg)
#
# - 20+ New Practice Questions
# - Concepts Revision from Week 1 to Week 5
#
# # [Practice Set 1, 20+ Questions 🔗](https://www.kaggle.com/code/param302/session-13a-oppe-1-revision-2-by-parampreet/)
#
# ### Mock OPPE 1 Solutions
# - [Mock OPPE 1a 🔗](https://www.kaggle.com/code/param302/iitmbs-mlp-oppe-1-mock-1)
# - [Mock OPPE 1b 🔗](https://www.kaggle.com/code/param302/iitmbs-mlp-oppe-1-mock-2)
#
# ### NPPE 1 Solutions
# - [NPPE OPPE 1a 🔗](https://www.kaggle.com/code/param302/iitm-mlp-nppe1-part1)
# - [NPPE OPPE 1b 🔗](https://www.kaggle.com/code/param302/iitm-mlp-nppe1-part2)
#
# #### [Session Playlist 🔗](https://www.youtube.com/playlist?list=PLClULgPbRPsA1twUfMlWkI4yJeqjsSi23)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/house-prices-advanced-regression-techniques/sample_submission.csv
# /kaggle/input/house-prices-advanced-regression-techniques/data_description.txt
# /kaggle/input/house-prices-advanced-regression-techniques/train.csv
# /kaggle/input/house-prices-advanced-regression-techniques/test.csv

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Q1: What are the unique values present in the `Neighborhood` feature?

# %% [markdown]
# ### Q2: Which columns contain categorical data (e.g., `MSZoning`, `FireplaceQu`)?

# %% [markdown]
# ### Q3: Identify features with missing (NaN) or unknown ("?") values in the dataset.

# %% [markdown]
# ### Q4: Create a new column 'HouseAge' as the difference between 'YrSold' and 'YearBuilt'. What is the median age of the houses?

# %% [markdown]
# ### Q5: How many houses were sold in the year 2008?

# %% [markdown]
# ### Q6: How many houses in the year 2023 have more than 3 bedrooms and a garage? (Ignore missing values)

# %% [markdown]
# Separate features (X) and target variable (y).
#
# Split the data into training and test sets 80:20 ratio.
#
# with:
# - random state 0
#
# ### Q7: What is the number of samples in the training set?

# %% [markdown]
# ### Q8: Replace missing values in the `Locality` feature with the most frequent value in the training set. What is the most frequent value?

# %% [markdown]
# ### Q9: Impute missing values in `LotArea` with the median value from the training set. What is the median value you get?

# %% [markdown]
# ### Q10: Use the mean value from the training set to fill missing values in `OverallCond`. What's the mean value you get?

# %% [markdown]
# ### Q11: Replace unknown ("?") or `nan` values in `MasVnrArea` with the most frequent value in the training set.

# %% [markdown]
# ### Q12: Apply the median value from the training set to impute missing values in `GarageCars`. What's the median value you get?

# %% [markdown]
# ### Q13: Remove the `Id` column before further processing.

# %% [markdown]
# ### Q14: Apply Min-Max scaling to all numerical features in both training and test sets.

# %% [markdown]
# ### Q15: Encode all categorical features using One-Hot Encoding on the training and test sets.

# %% [markdown]
# ### Q16: After scaling and encoding, how many total features are present in the training dataset?

# %% [markdown]
# ## Model Building:

# %% [markdown]
# ### Q1: Train a Linear Regression model on the training data. Evaluate its $R^2$ score on the test set.

# %% [markdown]
# ### Q2: Using KFold cross-validation (K=5), what is the maximum $R^2$ score achieved by a Linear Regression model on the training data?

# %% [markdown]
# ### Q3: Train a Lasso regression model with alpha=0.1 on the training data. What is the mean squared error on the test dataset?

# %% [markdown]
# ### Q4: Perform a 5-fold cross-validation with SGDRegressor. What is the average R2 score?

# %% [markdown]
# ### Q5: Use GridSearchCV to tune the hyperparameters of Ridge regression with alpha values [0.1, 1.0, 10]. What is the best alpha value?

# %% [markdown]
# ### Q6: Create a pipeline with PolynomialFeatures (degree=2) and Lasso (alpha=0.01). What is the R2 score on the test dataset?

# %% [markdown]
# ### Q7: Use SelectKBest with f_regression to select the top 10 features. What are the indices of the selected features?

# %% [markdown]
# ### Q8: Train a Ridge regression model with alpha=10 and solver='saga'. What is the index of the most important feature?

# %% [markdown]
# ### Q9: Train an SGDRegressor with a grid search over parameters penalty=['l1', 'l2'] and alpha=[0.0001, 0.001]. What is the best penalty?

# %% [markdown]
# ### Q10: Create a pipeline with PCA (n_components=0.95) and Ridge regression. What is the explained variance ratio of the first principal component?

# %% [markdown]
# ### Q11: Use RandomizedSearchCV to tune the hyperparameters of Lasso regression with alpha values from 0.001 to 1. What is the best alpha value?

# %% [markdown]
# ### Q12: Use RFECV with a LinearRegression model to select features. What is the optimal number of features?

# %% [markdown]
# Create a pipeline on original training & test data with:
# - Standard Scaler on Numerical features
# - Ordinal Encoding on columns with more than 5 unique values
# - One Hot Encoding on rest of categorical columns
# - MinMax Scaling on Ordinal Encoded columns
# - and use SGDRegressor.
#
# ### Q13: What is the mean absolute error on the test dataset?

# %% [markdown]
# Create a pipeline with PCA (n_components=0.95) and Ridge regression.
#
# ### Q14: What is the explained variance ratio of the first principal component?

# %% [markdown]
# ### Q15: How much variance is explained (eigenvalue) of the first principal component?

# %% [markdown]
# Create a pipeline with the following steps:
# 1. Impute missing values in 'LotFrontage' with SimpleImputer(strategy='median')
# 2. Impute rest of the columns with their mean value.
# 3. Scale 'LotArea' using StandardScaler
# 4. One-hot encode 'MSZoning'
# 5. Ordinal Encoder rest of the columns
# 6. Train a Ridge regression model with alpha=1.0
#
# ### Q16: What is the R2 score on the test dataset?

# %% [markdown]
# Create a pipeline with the following steps:
# 1. Impute missing values in 'GarageYrBlt' with KNNImputer(n_neighbors=5)
# 2. Impute rest of the columns with their median value.
# 3. Scale '1stFlrSF' using MinMaxScaler
# 4. One-hot encode 'Neighborhood'
# 5. Ordinal Encoder rest of the columns
# 6. Train a Lasso regression model with alpha=0.01
#
# ### Q17: What is the mean absolute error on the test dataset?

# %% [markdown]
# Create a pipeline with the following steps:
# 1. Impute missing values in 'MasVnrArea' with SimpleImputer(strategy='mean')
# 2. Impute rest of the columns with their median value.
# 3. Apply PolynomialFeatures(degree=2) to 'OverallQual'
# 4. Scale 'GrLivArea' using MaxAbsScaler
# 5. Ordinal Encode all the columns
# 6. Train an SGDRegressor with alpha=0.001 and penalty='l2'
#
# ### Q18:  What is the R2 score on the test dataset?

# %% [markdown]
# # MLP Session 13b - OPPE 1 Revision 2 with Practice Questions by Parampreet Singh
# ## [Session video 🔗](https://youtu.be/4x6mFTG5oEg)
#
# - 20+ New Practice Questions
# - Concepts Revision from Week 1 to Week 5
#
# # [Practice Set 1, 20+ Questions 🔗](https://www.kaggle.com/code/param302/session-13a-oppe-1-revision-2-by-parampreet/)
#
# ### Mock OPPE 1 Solutions
# - [Mock OPPE 1a 🔗](https://www.kaggle.com/code/param302/iitmbs-mlp-oppe-1-mock-1)
# - [Mock OPPE 1b 🔗](https://www.kaggle.com/code/param302/iitmbs-mlp-oppe-1-mock-2)
#
# ### NPPE 1 Solutions
# - [NPPE OPPE 1a 🔗](https://www.kaggle.com/code/param302/iitm-mlp-nppe1-part1)
# - [NPPE OPPE 1b 🔗](https://www.kaggle.com/code/param302/iitm-mlp-nppe1-part2)
#
# #### [Session Playlist 🔗](https://www.youtube.com/playlist?list=PLClULgPbRPsA1twUfMlWkI4yJeqjsSi23)
